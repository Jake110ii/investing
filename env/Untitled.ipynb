# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import ticker
import matplotlib.dates as mdates # mdateのインポート
import mpl_finance

# %%
os.system('pipenv install --upgrade mplfinance --skip-lock')
# Out:
# Installing --upgrade…
# WARNING: Parse error at "'--upgrad'": Expected W:(0-9A-Za-z)
# ✘ Installation Failed
# 256

# %%
pd.__version__, yf.__version__
# Out:
# ('1.3.5', '0.1.87')

# %%
ticker = yf.Ticker('VTI')
data1 = ticker.history(period='1y')
data1
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-07 00:00:00-05:00  234.043061  236.151379  233.826317  235.629227
# 2021-12-08 00:00:00-05:00  236.023334  236.821340  235.107094  236.643997
# 2021-12-09 00:00:00-05:00  235.974059  236.348423  234.259813  234.387894
# 2021-12-10 00:00:00-05:00  235.875530  236.318865  234.052927  235.983902
# 2021-12-13 00:00:00-05:00  235.954346  236.052872  233.629284  233.836182
# ...                               ...         ...         ...         ...
# 2022-12-01 00:00:00-05:00  204.830002  205.470001  202.789993  204.179993
# 2022-12-02 00:00:00-05:00  201.550003  204.479996  201.199997  203.990005
# 2022-12-05 00:00:00-05:00  202.509995  202.960007  199.250000  199.979996
# 2022-12-06 00:00:00-05:00  199.910004  200.050003  195.839996  196.979996
# 2022-12-07 00:00:00-05:00  199.910004  197.720001  196.179993  197.169998
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
np.__file__
# Out:
# '/Users/hayata/.local/share/virtualenvs/env-gQcjdwt1/lib/python3.7/site-packages/numpy/__init__.py'

# %%
ls -l /Users/hayata/.local/share/virtualenvs/env-gQcjdwt1/lib/python3.7/site-packages/
# Out:
# total 960
# drwxr-xr-x  25 hayata  staff     800 12  7 22:57 IPython/
# drwxr-xr-x   9 hayata  staff     288 12  7 22:57 Jinja2-3.1.2.dist-info/
# drwxr-xr-x   8 hayata  staff     256 12  7 22:57 MarkupSafe-2.1.1.dist-info/
# drwxr-xr-x   8 hayata  staff     256 12  7 22:57 PyYAML-6.0.dist-info/
# drwxr-xr-x  10 hayata  staff     320 12  7 22:57 Pygments-2.13.0.dist-info/
# drwxr-xr-x  10 hayata  staff     320 12  7 22:57 QtPy-2.3.0.dist-info/
# drwxr-xr-x   9 hayata  staff     288 12  7 22:56 Send2Trash-1.8.0.dist-info/
# drwxr-xr-x  13 hayata  staff     416 12  7 22:57 __pycache__/
# drwxr-xr-x   6 hayata  staff     192 12  7 22:57 _argon2_cffi_bindings/
# -rwxr-xr-x   1 hayata  staff  218744 12  7 22:57 _cffi_backend.cpython-37m-darwin.so*
# drwxr-xr-x   5 hayata  staff     160 12  7 22:51 _distutils_hack/
# -rw-r--r--   1 hayata  staff      23 12  7 22:56 _pyrsistent_version.py
# drwxr-xr-x   4 hayata  staff     128 12  7 22:57 _yaml/
# ...

# %%
less Pipfile
